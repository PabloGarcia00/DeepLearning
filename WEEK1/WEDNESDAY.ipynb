# %% [markdown]
# # Wednesday: Multi Layer Perceptron
#
# * the limitation of a perceptron
# * how a mlp of a perceptron trains
# * test neural network (mlp)

# %% [markdown]
# **Single Layer Perceptron**
#
# Can only make linear decision boundries, hence it cannot be used for more complex boundries

# %% [markdown]
# **Parameters of a neuron**
#
# * weights one for each connection
# * biases
#
# so given 2 weights i.e. for two features
#
# $$\Large y=w_1x_1 + w_2x_2 + b$$

# %% [markdown]
# ## The X Or probelm
#
# can be solved using two neurons with one hidden layer.
#
# why:
# * let's both neurons in the first layer can form a decision boundry
# * the hidden layer neuron can modify the functions from the existing neurons i.e. map the data into a new space
# * the hidden layer makes prediction based on this modification
#
#
# ![image.png](attachment:fd14f109-8565-4041-a572-085745d92a89.png)

# %% [markdown]
# ## Network with a single hidden layer
#
# * input $\mathbf{x} \in \mathbb{R}^n$
# * hidden $ \mathbf{W_1} \in \mathbb{R}^{m*n}, \mathbf{b_1} \in \mathbb{R}^m$
# * output $\mathbf{W_2} \in \mathbb{R}^{o*m}, \mathbf{b_2} \in \mathbb{R}^o$
# * activation function: $\sigma$
# * hyperparameter: number of layers

# %% [markdown]
# *We have a network with 10 inputs, a first hidden layer with 50
# neurons, a second hidden layer with 20 neurons and 5 output
# neurons. How many trainable parameters does this network have?*

# %% [markdown]
# ((current layer neurons c * previous layer neurons p)+1*c)
#
# * input 10 neurons
# * hidden
#     * 50 neurons
#     * 20 neurons
# * output 5 neurons
#
# $h_i=\sigma (W_i + b_i)$
#
# $$10 * 50 = 500 (hidden layer 1)\\  + 50 * 20 = 1500 (second hidden layer)\\  + 20 * 5 = 1600 (output layer)\\ + 75 = 1675 (bias terms for h1,2 and output)$$

# %% [markdown]
# # Activation functions
#
# Activation functions help map input values to a known range, which helps stabilize training and helps map values to a desired output in the last layer. The most popular activation functions include binary step, linear, sigmoid, tanh, ReLU, and Softmax.
#
# * ReLU (let's value through or not) $\{1, z > 0$ or $0, z < 0\}$:
# $$Relu(z) = max(0, z)$$
#
# $$\frac{dReLU}{dx}(z)$$
# * sigmoid (binary classification):
# $$\sigma(z) = \frac{1} {1 + e^{-z}}$$
# $$\frac{d\sigma (x)}{d(x)} = \sigma (x)\cdot (1-\sigma(x))$$
# * tanh (binary classification):
# $$\tanh(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}} = \frac{1 - e^{-2x}}{1 + e^{-2x}}$$
#
# $$ \frac{d}{dx} tanh(x) = 1 - \frac{(e^x - e^-x)^2}{(e^x + e^-x)^2}$$

# %% [markdown]
# # training: Backpropagation
#
# * flow the data through the model
# * comparing the output with the actual value i.e. its **Loss** (classification or regression error)
# * we walk backward to calculate the effect of ever neuron and update its weights
#     * high value weights influence the output greatly while low value weights influence it less so
#     * combining derivatives to tune the weights
#
#
# So update $W_i$ by doing $W_1 = W_1 - \lambda * L'(W_1)$ the minus sign as were doing gradient decent. After forward propagation we can calculate the cost using a loss function. Then do backpropagation by taking the derivatives of each of the components in the graph below unil we reach the of weight in the weight matrices $\mathbf{W_i}$.
# ![image.png](attachment:44ff7477-8079-4e32-959d-446ecb6873aa.png)

# %% [markdown]
# ## Loss functions
#
# * Regression: $L = l(\hat{y}, y) = \frac{1}{2} * (\hat{y}  - y)^2, L' = \hat{y} - y$
# * classification (cross entropy loss): $-\sum_{j} y_j \log{(p_{\hat{y}})}$

# %% [markdown]
# ![image.png](attachment:76a7cd19-1443-4ba4-bea9-0407824bf462.png)

# %% [markdown]
# ![image.png](attachment:90ad12c1-e2f1-4a72-b03b-ee751c47cf76.png)
